# %% [markdown]
# <a href="https://colab.research.google.com/github/AshaMariam/AshaMariam_ExitTest/blob/main/AshaMariam_ExitTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Data Loading
df = pd.read_csv('/content/Obesity.csv')
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
# Data Exploration
df.shape
# Out:
# (2111, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2102 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2101 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2105 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2102 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2104 non-null   object
# ...

# %%
df.describe().T
# Out:
#          count       mean        std    min        25%        50%         75%  \
# Age     2111.0  24.488346   7.365358   2.00  19.947192  22.804818   26.000000
# Height  2101.0   1.701995   0.093288   1.45   1.630000   1.701284    1.768834
# Weight  2111.0  86.586058  26.191172  39.00  65.473343  83.000000  107.430682
# FCVC    2111.0   2.419043   0.533927   1.00   2.000000   2.385502    3.000000
# NCP     2111.0   2.685628   0.778039   1.00   2.658738   3.000000    3.000000
# CH2O    2111.0   2.008011   0.612953   1.00   1.584812   2.000000    2.477420
# FAF     2111.0   1.010298   0.850592   0.00   0.124505   1.000000    1.666678
# TUE     2111.0   0.657866   0.608927   0.00   0.000000   0.625350    1.000000
#
#            max
# Age      99.00
# Height    1.98
# Weight  173.00
# FCVC      3.00
# NCP       4.00
# CH2O      3.00
# FAF       3.00
# TUE       2.00

# %%
# Data Visualization
plt.figure(figsize = (12, 10))
sns.heatmap(df.corr(),
           annot = True,
           cmap = "Blues_r",
           linewidths = 2,
           linecolor = "white")
plt.title("Correlation matrix of obesity data")
plt.show()
# Out:
# <ipython-input-196-1914077cfe0e>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=df)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Age, Height, Weight
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.subplot(1, 3, 2)
sns.histplot(df['Height'], bins=20, kde=True)
plt.title('Height Distribution')
plt.xlabel('Height')
# Out:
# Text(0.5, 0, 'Height')

# %%
plt.subplot(1, 3, 3)
sns.histplot(df['Weight'], bins=20, kde=True)
plt.title('Weight Distribution')
plt.xlabel('Weight')
plt.show()

# %%
# Eating Habits
plt.figure(figsize=(18, 10))
plt.subplot(2, 3, 1)
sns.boxplot(x='FCVC', data=df)
plt.title('Frequency of Consumption of Vegetables')

plt.subplot(2, 3, 2)
sns.boxplot(x='NCP', data=df)
plt.title('Number of Main Meals per Day')

plt.subplot(2, 3, 3)
sns.boxplot(x='CH2O', data=df)
plt.title('Consumption of Water Daily')

plt.subplot(2, 3, 4)
sns.countplot(x='FAVC', data=df)
plt.title('Frequent Consumption of High Caloric Food')

plt.subplot(2, 3, 5)
sns.countplot(x='CAEC', data=df)
plt.title('Consumption of Food Between Meals')

plt.subplot(2, 3, 6)
sns.histplot(df['CALC'], bins=20, kde=True)
plt.title('Consumption of Alcohol')
plt.show()

# %%
# Physical Condition
plt.figure(figsize=(18, 8))
plt.subplot(2, 2, 1)
sns.countplot(x='SCC', data=df)
plt.title('Calories Consumption Monitoring')

plt.subplot(2, 2, 2)
sns.histplot(df['FAF'], bins=20, kde=True)
plt.title('Physical Activity Frequency')

plt.subplot(2, 2, 3)
sns.histplot(df['TUE'], bins=20, kde=True)
plt.title('Time Using Technology Devices')

plt.subplot(2, 2, 4)
sns.countplot(x='MTRANS', data=df)
plt.title('Transportation Used')
plt.show()

# %%
# Data Preprocessing
df.rename(columns={'NObeyesdad':'Weight_Category'}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                             9
# Age                                0
# Height                            10
# Weight                             0
# family_history_with_overweight     6
# FAVC                               0
# FCVC                               0
# NCP                                0
# CAEC                               9
# SMOKE                              0
# CH2O                               0
# SCC                                7
# FAF                                0
# TUE                                0
# CALC                               0
# MTRANS                             7
# Weight_Category                    0
# dtype: int64

# %%
# Imputing null values with mean
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-205-fc9463c56523>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                            9
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    6
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              9
# SMOKE                             0
# CH2O                              0
# SCC                               7
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            7
# Weight_Category                   0
# dtype: int64

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# Impute missing values for family_history_with_overweight with mode
df['family_history_with_overweight'].fillna(df['family_history_with_overweight'].mode()[0], inplace=True)

# Impute missing values for CAEC, SCC, MTRANS with mode
df['CAEC'].fillna(df['CAEC'].mode()[0], inplace=True)
df['SCC'].fillna(df['SCC'].mode()[0], inplace=True)
df['MTRANS'].fillna(df['MTRANS'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# Weight_Category                   0
# dtype: int64

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS      Weight_Category
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
# Split the dataset into features (X) and target variable (y)
y = df['Weight_Category']
X = df.drop('Weight_Category', axis=1)

# Handling Categorical Variables
# Encoding binary categorical variables
# Imputing missing values for binary variables
# One-hot encoding for remaining categorical variables
# Encode binary categorical variables with 'yes' and 'no' values
binary_columns = ['family_history_with_overweight', 'FAVC', 'SMOKE', 'SCC']

for column in binary_columns:
    X[column] = X[column].map({'yes': 1, 'no': 0})

# Perform one-hot encoding for the remaining categorical variables
X_encoded = pd.get_dummies(X, columns=['Gender', 'MTRANS', 'CAEC', 'CALC'])

# Split the dataset into features (X) and target variable (y)
y = df['Weight_Category']

# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)


# Choose a machine learning model
from sklearn.ensemble import RandomForestClassifier

# Initialize the classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
clf.fit(X_train, y_train)

# Evaluate the model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

y_pred = clf.predict(X_test)

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[54  2  0  0  0  0  0]
#  [ 2 54  0  0  0  5  1]
#  [ 0  1 75  2  0  0  0]
#  [ 0  0  1 57  0  0  0]
#  [ 0  0  0  0 63  0  0]
#  [ 0  5  0  0  0 50  1]
#  [ 0  0  0  0  0  3 47]]
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.96      0.96      0.96        56
#       Normal_Weight       0.87      0.87      0.87        62
#      Obesity_Type_I       0.99      0.96      0.97        78
#     Obesity_Type_II       0.97      0.98      0.97        58
#    Obesity_Type_III       1.00      1.00      1.00        63
#  Overweight_Level_I       0.86      0.89      0.88        56
# Overweight_Level_II       0.96      0.94      0.95        50
#
#            accuracy                           0.95       423
#           macro avg       0.94      0.94      0.94       423
#        weighted avg       0.95      0.95      0.95       423
#
#
# Accuracy Score: 0.9456264775413712

# %%
# Importing necessary libraries
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Split the dataset into features (X) and target variable (y)
y = df['Weight_Category']
X = df.drop('Weight_Category', axis=1)

binary_columns = ['family_history_with_overweight', 'FAVC', 'SMOKE', 'SCC']
for column in binary_columns:
    X[column] = X[column].map({'yes': 1, 'no': 0})

X_encoded = pd.get_dummies(X, columns=['Gender', 'MTRANS', 'CAEC', 'CALC'])



# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Initialize and train the Support Vector Machine (SVM) classifier
svm_classifier = SVC(kernel='linear', random_state=42)
svm_classifier.fit(X_train, y_train)

# Make predictions
y_pred = svm_classifier.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[56  0  0  0  0  0  0]
#  [11 39  0  0  0 11  1]
#  [ 0  0 71  4  0  1  2]
#  [ 0  0  0 58  0  0  0]
#  [ 0  0  0  0 63  0  0]
#  [ 0  4  0  0  0 48  4]
#  [ 0  0  7  0  0  6 37]]
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.84      1.00      0.91        56
#       Normal_Weight       0.91      0.63      0.74        62
#      Obesity_Type_I       0.91      0.91      0.91        78
#     Obesity_Type_II       0.94      1.00      0.97        58
#    Obesity_Type_III       1.00      1.00      1.00        63
#  Overweight_Level_I       0.73      0.86      0.79        56
# Overweight_Level_II       0.84      0.74      0.79        50
#
#            accuracy                           0.88       423
#           macro avg       0.88      0.88      0.87       423
#        weighted avg       0.88      0.88      0.88       423
#
#
# Accuracy Score: 0.8794326241134752

# %%
from sklearn.linear_model import LogisticRegression

# Initialize and train the logistic regression model
logistic_regression = LogisticRegression()
logistic_regression.fit(X_train, y_train)

# Make predictions
y_pred_lr = logistic_regression.predict(X_test)

# Evaluate the model
print("Logistic Regression Results:")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_lr))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_lr))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred_lr))
# Out:
# Logistic Regression Results:
# Confusion Matrix:
# [[52  4  0  0  0  0  0]
#  [11 36  1  1  0  8  5]
#  [ 0  0 39 13  6  2 18]
#  [ 0  0  2 55  0  0  1]
#  [ 0  0  0  0 63  0  0]
#  [ 0  8  4  0  0 31 13]
#  [ 0  3  9  4  0 10 24]]
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.83      0.93      0.87        56
#       Normal_Weight       0.71      0.58      0.64        62
#      Obesity_Type_I       0.71      0.50      0.59        78
#     Obesity_Type_II       0.75      0.95      0.84        58
#    Obesity_Type_III       0.91      1.00      0.95        63
#  Overweight_Level_I       0.61      0.55      0.58        56
# Overweight_Level_II       0.39      0.48      0.43        50
#
#            accuracy                           0.71       423
#           macro avg       0.70      0.71      0.70       423
#        weighted avg       0.71      0.71      0.70       423
#
#
# Accuracy Score: 0.7092198581560284
# ...

# %%
from sklearn.naive_bayes import GaussianNB

# Initialize and train the Gaussian Naive Bayes classifier
naive_bayes_classifier = GaussianNB()
naive_bayes_classifier.fit(X_train, y_train)

# Make predictions
y_pred_nb = naive_bayes_classifier.predict(X_test)

# Evaluate the model
print("Naive Bayes Results:")
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_nb))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_nb))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred_nb))
# Out:
# Naive Bayes Results:
# Confusion Matrix:
# [[49  0  6  0  0  1  0]
#  [35  8  5  0  0  6  8]
#  [ 0  2 32 37  0  2  5]
#  [ 0  0  0 57  0  0  1]
#  [ 0  0  0  0 63  0  0]
#  [14  3 19  6  0  7  7]
#  [ 3  2 17 13  0  0 15]]
#
# Classification Report:
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.49      0.88      0.62        56
#       Normal_Weight       0.53      0.13      0.21        62
#      Obesity_Type_I       0.41      0.41      0.41        78
#     Obesity_Type_II       0.50      0.98      0.67        58
#    Obesity_Type_III       1.00      1.00      1.00        63
#  Overweight_Level_I       0.44      0.12      0.19        56
# Overweight_Level_II       0.42      0.30      0.35        50
#
#            accuracy                           0.55       423
#           macro avg       0.54      0.55      0.49       423
#        weighted avg       0.54      0.55      0.50       423
#
#
# Accuracy Score: 0.5460992907801419

# %% [markdown]
# In this analysis, i have explored the performance of several machine learning models for predicting weight categories based on various features related to obesity. Among the models tested, including Random Forest, Support Vector Machine, Logistic Regression, and Gaussian Naive Bayes, the Random Forest classifier gives the highest accuracy.
#
# The Random Forest classifier achieved an accuracy score of 94%.
